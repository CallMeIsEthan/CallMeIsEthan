# %% [markdown]
# <a href="https://colab.research.google.com/github/CallMeIsEthan/CallMeIsEthan/blob/main/Minimax_AlphaBeta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
